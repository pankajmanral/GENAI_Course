# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model='gemini-3.1-flash-lite')

# %%
prompt = [
    ("system", "You are a senior java developer."),
    ("user", "How to sort an array")
]

# %%
response = llm.invoke(prompt)

# %%
print(response.content[0]["text"])
# Out:
# As a senior Java developer, I recommend different approaches depending on your specific requirements (performance, readability, or data type).
#
# Here is the breakdown of how to sort arrays in Java.
#
# ---
#
# ### 1. Using `java.util.Arrays` (The Standard Way)
# For primitive arrays (`int[]`, `double[]`, etc.) or arrays of objects that implement `Comparable`, the `Arrays.sort()` method is the standard.
#
# *   **Primitives:** Uses a Dual-Pivot Quicksort (O(n log n)).
# *   **Objects:** Uses TimSort (O(n log n)).
#
# ```java
# import java.util.Arrays;
#
# // 1. Primitive array
# int[] numbers = {5, 2, 8, 1};
# Arrays.sort(numbers); // [1, 2, 5, 8]
#
# // 2. Object array (Strings implement Comparable)
# String[] names = {"Charlie", "Alice", "Bob"};
# Arrays.sort(names); // [Alice, Bob, Charlie]
# ```
#
# ---
#
# ### 2. Sorting in Reverse Order
# When sorting objects (like `Integer[]` or `String[]`), you can provide a `Comparator`. Note that **you cannot use `Collections.reverseOrder()` on a primitive array** (like `int[]`); you would need to use an `Integer[]` wrapper array or sort and then reverse.
#
# ```java
# import java.util.Arrays;
# import java.util.Collections;
#
# Integer[] numbers = {1, 5, 2, 8};
# Arrays.sort(numbers, Collections.reverseOrder()); // [8, 5, 2, 1]
# ```
#
# ---
#
# ### 3. Custom Sorting (Using Lambdas)
# If you are sorting custom objects (e.g., a `User` class), use a Comparator. This is cleaner and more readable than implementing `Comparable`.
#
# ```java
# User[] users = { new User("Alice", 30), new User("Bob", 20) };
#
# // Sort by age
# Arrays.sort(users, (a, b) -> Integer.compare(a.getAge(), b.getAge()));
#
# // Modern approach (Java 8+)
# Arrays.sort(users, Comparator.comparingInt(User::getAge));
# ```
#
# ---
#
# ### 4. Sorting with Streams (Functional Approach)
# If you want to keep the original array immutable or perform sorting as part of a data pipeline, use the Stream API. Note that this **creates a new sorted array** rather than sorting in-place.
#
# ```java
# int[] numbers = {5, 2, 8, 1};
#
# int[] sortedNumbers = Arrays.stream(numbers)
#                             .sorted()
#                             .toArray();
# ```
#
# ---
#
# ### Summary Checklist: Which one should you use?
#
# | Scenario | Recommended Method |
# | :--- | :--- |
# | **Simple primitive sort** | `Arrays.sort(arr)` |
# | **Object sorting (natural order)** | `Arrays.sort(arr)` |
# | **Custom object sorting** | `Arrays.sort(arr, Comparator.comparing(...))` |
# | **Descending order** | `Arrays.sort(arr, Collections.reverseOrder())` |
# | **Functional pipeline** | `Arrays.stream(arr).sorted()...` |
#
# ### Pro-Tip: The "Gotcha"
# Remember that `Arrays.sort()` on objects uses **TimSort**, which is a **stable sort**. This means that if two objects are "equal" according to your comparator, their original relative order is preserved. This is a critical feature when sorting by multiple fields (e.g., sort by name, then by date).
